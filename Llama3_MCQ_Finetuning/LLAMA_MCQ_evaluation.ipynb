# %%
import pandas as pd

# Replace 'file_path.csv' with the path to your CSV file
file_path = '/content/drive/MyDrive/final_evaluation_results.csv'

# Load the CSV file into a DataFrame
model_output = pd.read_csv(file_path)
model_output
# Out:
#                                        Predicted Output  True Label
# 0     Answer the following question by returning one...           2
# 1     Answer the following question by returning one...           4
# 2     Answer the following question by returning one...           2
# 3     Answer the following question by returning one...           4
# 4     Answer the following question by returning one...           2
# ...                                                 ...         ...
# 1268  Answer the following question by returning one...           4
# 1269  Answer the following question by returning one...           4
# 1270  Answer the following question by returning one...           2
# 1271  Answer the following question by returning one...           3
# 1272  Answer the following question by returning one...           3
#
# [1273 rows x 2 columns]

# %%
model_output['Predicted Output'] = model_output['Predicted Output'].str.extract(r'Answer\s*:? :?\s*(?:Option\s*)?(\d+)')
model_output['Predicted Output'] = model_output['Predicted Output'].fillna(0).astype(int)  # Replace NaN with 0
for i in range(len(model_output['Predicted Output'])):
  if model_output['Predicted Output'][i]==0:
    model_output.drop(i, inplace=True)

model_output
# Out:
#       Predicted Output  True Label
# 0                    2           2
# 1                    2           4
# 4                    2           2
# 6                    2           3
# 9                    2           1
# ...                ...         ...
# 1264                 4           2
# 1266                 4           3
# 1268                 4           4
# 1271                 3           3
# 1272                56           3
#
# [591 rows x 2 columns]

# %%
correct_predictions = (model_output['True Label'] == model_output['Predicted Output']).sum()

# Calculate accuracy
total_samples = len(model_output)
accuracy = correct_predictions / total_samples

print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 59.39%
